# %%
# !pip3 install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 7.8 MB 6.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.0 MB 22.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 111 kB 20.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 64 kB 6.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.7 MB 2.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 249 kB 24.8 MB/s eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import requests
import pandas
import matplotlib

url = "https://api.octopus.energy/v1/products/AGILE-18-02-21/electricity-tariffs/E-1R-AGILE-18-02-21-G/standard-unit-rates/"
response = requests.get(url, params={"period_from": "2024-05-15T00:00Z", "period_to": "2024-05-16T00:00Z"})
data = response.json()
prices = [(item['valid_from'], item['value_inc_vat']) for item in data['results']]

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['valid_from'], df['value_inc_vat'])
plt.xlabel('Time')
plt.ylabel('Price (inc VAT)')
plt.title('Electricity Prices Over Time')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
